78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78,78])
resnet_FCB_loss = np.array([2.13,1.96,1.81,1.71,1.62,1.55,1.49,1.42,1.36,1.30,1.25,1.21,1.17,1.11,1.07,1.03,1.00,0.96,0.94,0.90,0.88,0.83,0.81,0.78,0.75,0.72,0.69,0.66,0.64,0.63,0.58,0.57,0.54,0.53,0.49,0.49,0.43,0.41,0.40,0.37,0.35,0.33,0.29,0.27,0.27,0.26,0.22,0.19,0.17,0.19,0.14,0.13,0.12,0.13,0.09,0.11,0.13,0.06,0.08,0.08,0.07,0.07,0.06,0.08,0.08,0.08,0.04,0.05,0.03,0.03,0.02,0.03,0.05,0.02,0.04,0.04,0.01,0.06,0.03,0.02,0.03,0.03,0.02,0.03,0.02,0.03,0.03,0.06,0.02,0.03,0.02,0.02,0.03,0.01])
# # 绘制第一张子图（模型1的Accuracy曲线）
# convnet_acc_line_ab = ax[0, 0].plot(epoch, convnet_all_binary_acc, label='convnet')
ax[0, 0].plot(epoch, simpleCNN_FL_acc, label='simplecnn',color = '#c1272d')
ax[0, 0].plot(epoch, simpleCNN_all_binary_acc, label='simplecnn',color = '#0000a7')
ax[0, 0].plot(epoch, simpleCNN_FCB_acc, label='simplecnn',color = '#008176')
# ax[0, 0].set_xlabel('Global Epoch')
ax[0, 0].set_ylabel('Test Accuracy')
ax[0, 0].set_title('(a) SimpleCNN Accuracy')
ax[0, 0].grid()

# 绘制第二张子图（模型1的Loss曲线）
# model1_loss_line, = ax[1, 0].plot(epoch, model1_loss, label='Model 1'
ax[1, 0].plot(epoch, simpleCNN_FL_loss, label='simplecnn',color = '#c1272d')     
ax[1, 0].plot(epoch, simpleCNN_all_binary_loss, label='simplecnn',color = '#0000a7')
ax[1, 0].plot(epoch, simpleCNN_FCB_loss, label='simplecnn',color = '#008176')
# ax[1, 0].set_xlabel('Global Epoch')
ax[1, 0].set_ylabel('Training Loss')
ax[1, 0].set_title('(b) SimpleCNN Loss')
ax[1, 0].grid()

# model2_acc_line2, = ax[0, 1].plot(epoch, model2_acc, label='Model 2',color='red')
convnet_acc_line_ab, = ax[0, 1].plot(epoch, convnet_all_binary_acc, label='convnet',color = '#0000a7')
convnet_acc_line_fl, = ax[0, 1].plot(epoch, convnet_FL_acc, label='convnet',color = '#c1272d')
convnet_acc_line_fcb, = ax[0, 1].plot(epoch, convnet_FCB_acc, label='convnet',color = '#008176')
# ax[0, 1].set_xlabel('Global Epoch')
# ax[0, 1].set_ylabel('Test Accuracy')
ax[0, 1].set_title('(c) ConvNet Accuracy')
ax[0, 1].grid()

# model1_loss_line2, = ax[1, 1].plot(epoch, model1_loss, label='Model 2')
convnet_loss_line_ab, = ax[1, 1].plot(epoch, convnet_all_binary_loss, label='convnet',color = '#0000a7')  # 添加第二个折线     
convnet_loss_line_fl, = ax[1, 1].plot(epoch, convnet_FL_loss, label='convnet',color = '#c1272d')  # 添加第二个折线  
convnet_loss_line_fbc, = ax[1, 1].plot(epoch, convnet_FCB_loss, label='convnet',color = '#008176') 
ax[1, 1].set_xlabel('Global Epoch')
# ax[1, 1].set_ylabel('Training Loss')
ax[1, 1].set_title('(d) ConvNet Loss')
ax[1, 1].grid()

ax[0, 2].plot(epoch, resnet_FL_acc, label='resnet',color = '#c1272d')
ax[0, 2].plot(epoch, resnet_FCB_acc, label='resnet',color = '#008176')
# ax[0, 2].set_xlabel('Global Epoch')
# ax[0, 2].set_ylabel('Test Accuracy')
ax[0, 2].set_title('(e) ResNet18 Accuracy')
ax[0, 2].grid()

ax[1, 2].plot(epoch, resnet_FL_loss, label='resnet',color = '#c1272d')
ax[1, 2].plot(epoch, resnet_FCB_loss, label='resnet',color = '#008176')
# ax[1, 2].set_xlabel('Global Epoch')
# ax[1, 2].set_ylabel('Training Loss')
ax[1, 2].set_title('(f) ResNet18 Accuracy')
ax[1, 2].grid()
# 添加共享图例
handles = [convnet_acc_line_ab, convnet_acc_line_fl,convnet_loss_line_fbc]
labels = ['Binary Conversion on All layers', 'Only FL','Binary Conversion on FC layer']
fig.legend(handles, labels, loc='lower center', ncol=4, fontsize=12)

plt.show()

# %%
from PIL import Image

# 创建一个32x32的空白图像
img_null_0 = Image.new(mode='RGBA', size=(389, 389), color='white')
# 保存图像为PNG格式
img.save('blank_image.png')

# %%
img1.size
# Out:
# (389, 389)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# 读取图片
img1 = Image.open("sunflower_ground_truth.png")
img2 = Image.open("sunflower_JoPEQ_R8.png")
img3 = Image.open("sunflower_JoPEQ_R16.png")
img4 = Image.open("sunflower_JoPEQ_R32.png")
img5 = Image.open("sunflower_Lattice_quantization_R8.png")
img6 = Image.open("sunflower_Lattice_quantization_R16.png")
img7 = Image.open("sunflower_Lattice_quantization_R32.png")
img8 = Image.open("sunflower_SCDP_R8.png")
img9 = Image.open("sunflower_SCDP_R16.png")
img10 = Image.open("sunflower_SCDP_R32.png")
# 设置subplot布局
fig, axs = plt.subplots(nrows=3, ncols=5, figsize=(15, 8))
axs = axs.ravel()

# 在subplot中显示每张图像
for i, img in enumerate([img1,img_null_0,img5, img6, img7,img_null_0, img_null_0, img2, img3, img4,img_null_0,img_null_0,img8,img9,img10]):
    axs[i].imshow(img)
    axs[i].axis("off")
#     plt.text(0,0,"xxxx",size=20)

# 添加行和列标注
for ax, col in zip(axs[:5], ['Ground Truth', '','R = 8', 'R = 16', 'R = 32']):
    ax.set_title(col)

for ax, row in zip(axs[::4], ['Row 1', 'Row 2', 'Row 3', 'Row 4']):
    ax.set_ylabel(row)

plt.text(-1500,-700,'Lattice Quantization',size=12)
plt.text(-1300,-250,'JoPEQ',size=12)
plt.text(-1300,200,'Ours',size=12)

plt.savefig(fname='./combined.png', format = 'png')
# # 合并图像并保存
# images = [np.array(img1), np.array(img5), np.array(img6), np.array(img7), np.array(img_null_0), np.array(img2), np.array(img3),np.array(img4),np.array(img_null_0),np.array(img8),np.array(img9),np.array(img10)]
# combined_image = np.concatenate(images, axis=1)
# Image.fromarray(combined_image).save("combined_image.png")

# # 显示合并后的图像
# plt.figure(figsize=(12, 6))
# plt.imshow(combined_image)
# plt.axis("off")
# plt.show()
